# %%
# ==========================================
# FASE 5: EVALUACIÓN (EVALUATION - CRISP-DM)
# ==========================================

import pandas as pd
import time
import sys

# 1. Le decimos a Python que busque módulos en la carpeta 'src'
sys.path.append('../src')
from evaluador import evaluar_modelo_recomendacion

# 2. Cargar los datos
df = pd.read_csv("C:/Users/basti/proyecto_cd/data/processed/spotify_dataset_processed.csv", sep=",")
features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

# 3. Definir la canción semilla de prueba (LA MISMA PARA TODOS LOS MODELOS)
track_id_prueba = df['track_id'].iloc[100]
vector_semilla = df[df['track_id'] == track_id_prueba][features]

print("Canción semilla para la prueba comparativa seleccionada.")

# ---------------------------------------------------------
# PRUEBA 1: MODELO KNN (Tu modelo)
# ---------------------------------------------------------

inicio_knn = time.time()

# Desempaquetamos los dos retornos de la función
textos_knn, vectores_recomendados_knn = recomendar_canciones_knn(
    track_id_semilla=track_id_prueba, 
    modelo=knn_model, 
    dataframe=df, 
    features_list=features, 
    top_k=5
)

fin_knn = time.time()

# ¡Evaluamos usando los vectores!
evaluar_modelo_recomendacion("K-Nearest Neighbors (KNN)", vector_semilla, vectores_recomendados_knn, inicio_knn, fin_knn)

# ---------------------------------------------------------
# PRUEBA 2: MODELO K-MEANS (El modelo de tu compañero)
# ---------------------------------------------------------
# (Asumiendo que tu compañero ya agrupó y tiene las predicciones)

inicio_kmeans = time.time()
# Tu compañero extrae 5 canciones del mismo clúster de la semilla
vectores_recomendados_kmeans = df.iloc[indices_de_kmeans][features]
fin_kmeans = time.time()

# ¡AQUÍ USAN EL MISMO EVALUADOR!
evaluar_modelo_recomendacion("K-Means (Clustering Global)", vector_semilla, vectores_recomendados_kmeans, inicio_kmeans, fin_kmeans)
